# %%
from experiments.experiment_running import run_all_experiments, run_experiment
def fitness():
    pass
#run_all_experiments(reverse_order=True, experiment_verbose=2, fit_verbose=0, model_verbose=1)
run_experiment('imp','cnn',32, '1h', 2, 1)
# Out:
# Using TensorFlow backend.
# 2020-10-21 19:52:12.754708
# ./pkl/experiments/_regression_gran30min_period4_lags8_model-mlp_user59_imp.pkl
# 1/9216 fishished experiments
# ##########
# ##########
# ##########
#
#
# 2020-10-21 19:52:12.755545
# ./pkl/experiments/_regression_gran30min_period2_lags8_model-mlp_user59_imp.pkl
# 2/9216 fishished experiments
# ##########
# ##########
# ##########
#
#
# 2020-10-21 19:52:12.756560
# ./pkl/experiments/_regression_gran30min_period1_lags8_model-mlp_user59_imp.pkl
# 3/9216 fishished experiments
# ##########
# ##########
# ##########
#
#
# 2020-10-21 19:52:12.756560
# ./pkl/experiments/_regression_gran30min_period4_lags4_model-mlp_user59_imp.pkl
# 4/9216 fishished experiments
# ##########
# ##########
# ##########
#
#
# 2020-10-21 19:52:12.757559
# ./pkl/experiments/_regression_gran30min_period2_lags4_model-mlp_user59_imp.pkl
# 5/9216 fishished experiments
# ##########
# ##########
# ##########
#
#
# 2020-10-21 19:52:12.759559
# ...

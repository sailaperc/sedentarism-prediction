# %%
from experiments.experiment_running import run_all_experiments
def fitness():
    pass
run_all_experiments(reverse_order=True, experiment_verbose=2, fit_verbose=0, model_verbose=1)
# Out:
# 1415/6912 fishished experiments
# ##########
# ##########
# ##########
#
#
# 2020-10-13 17:52:14.063602
# ./pkl/experiments/_regression_gran1h_period1_lags1_model-tcn_user46_imp.pkl
# 1416/6912 fishished experiments
# ##########
# ##########
# ##########
#
#
# 2020-10-13 17:52:14.064602
# ./pkl/experiments/_regression_gran30min_period4_lags8_model-tcn_user45_imp.pkl
# 1417/6912 fishished experiments
# ##########
# ##########
# ##########
#
#
# 2020-10-13 17:52:14.065603
# ./pkl/experiments/_regression_gran30min_period2_lags8_model-tcn_user45_imp.pkl
# 1418/6912 fishished experiments
# ##########
# ##########
# ##########
#
#
# 2020-10-13 17:52:14.065603
# ./pkl/experiments/_regression_gran30min_period1_lags8_model-tcn_user45_imp.pkl
# 1419/6912 fishished experiments
# ##########
# ##########
# ##########
#
#
# 2020-10-13 17:52:14.066603
# ./pkl/experiments/_regression_gran30min_period4_lags4_model-tcn_user45_imp.pkl
# 1420/6912 fishished experiments
# ##########
# ##########
# ##########
#
#
# 2020-10-13 17:52:14.067602
# ./pkl/experiments/_regression_gran30min_period2_lags4_model-tcn_user45_imp.pkl
# 1421/6912 fishished experiments
# ##########
# ##########
# ##########
#
#
# 2020-10-13 17:52:14.068602
# ./pkl/experiments/_regression_gran30min_period1_lags4_model-tcn_user45_imp.pkl
# 1422/6912 fishished experiments
# ##########
# ##########
# ##########
#
#
# 2020-10-13 17:52:14.069602
# ./pkl/experiments/_regression_gran30min_period4_lags2_model-tcn_user45_imp.pkl
# 1423/6912 fishished experiments
# ##########
# ##########
# ##########
#
#
# 2020-10-13 17:52:14.081634
# ./pkl/experiments/_regression_gran30min_period2_lags2_model-tcn_user45_imp.pkl
# 1424/6912 fishished experiments
# ##########
# ##########
# ##########
#
#
# 2020-10-13 17:52:14.098600
# ./pkl/experiments/_regression_gran30min_period1_lags2_model-tcn_user45_imp.pkl
# 1425/6912 fishished experiments
# ##########
# ##########
# ##########
#
#
# 2020-10-13 17:52:14.100599
# ./pkl/experiments/_regression_gran30min_period4_lags1_model-tcn_user45_imp.pkl
# 1426/6912 fishished experiments
# ##########
# ##########
# ##########
#
#
# 2020-10-13 17:52:14.102603
# ./pkl/experiments/_regression_gran30min_period2_lags1_model-tcn_user45_imp.pkl
# 1427/6912 fishished experiments
# ##########
# ##########
# ##########
#
#
# 2020-10-13 17:52:14.106670
# ./pkl/experiments/_regression_gran30min_period1_lags1_model-tcn_user45_imp.pkl
# 1428/6912 fishished experiments
# ##########
# ##########
# ##########
#
#
# 2020-10-13 17:52:14.111602
# ./pkl/experiments/_regression_gran1h_period4_lags8_model-tcn_user45_imp.pkl
# 1429/6912 fishished experiments
# ##########
# ##########
# ##########
#
#
# 2020-10-13 17:52:14.111602
# ./pkl/experiments/_regression_gran1h_period2_lags8_model-tcn_user45_imp.pkl
# 1430/6912 fishished experiments
# ##########
# ##########
# ##########
#
#
# 2020-10-13 17:52:14.112603
# ./pkl/experiments/_regression_gran1h_period1_lags8_model-tcn_user45_imp.pkl
# 1431/6912 fishished experiments
# ##########
# ##########
# ##########
#
#
# 2020-10-13 17:52:14.113602
# ./pkl/experiments/_regression_gran1h_period4_lags4_model-tcn_user45_imp.pkl
# 1432/6912 fishished experiments
# ##########
# ##########
# ##########
#
#
# 2020-10-13 17:52:14.113602
# ./pkl/experiments/_regression_gran1h_period2_lags4_model-tcn_user45_imp.pkl
# 1433/6912 fishished experiments
# ##########
# ##########
# ##########
#
#
# 2020-10-13 17:52:14.114601
# ./pkl/experiments/_regression_gran1h_period1_lags4_model-tcn_user45_imp.pkl
# 1434/6912 fishished experiments
# ##########
# ##########
# ##########
#
#
# 2020-10-13 17:52:14.115601
# ./pkl/experiments/_regression_gran1h_period4_lags2_model-tcn_user45_imp.pkl
# 1435/6912 fishished experiments
# ##########
# ##########
# ##########
#
#
# 2020-10-13 17:52:14.116602
# ./pkl/experiments/_regression_gran1h_period2_lags2_model-tcn_user45_imp.pkl
# 1436/6912 fishished experiments
# ##########
# ##########
# ##########
#
#
# 2020-10-13 17:52:14.117602
# ./pkl/experiments/_regression_gran1h_period1_lags2_model-tcn_user45_imp.pkl
# 1437/6912 fishished experiments
# ##########
# ##########
# ##########
#
#
# 2020-10-13 17:52:14.118601
# ./pkl/experiments/_regression_gran1h_period4_lags1_model-tcn_user45_imp.pkl
# 1438/6912 fishished experiments
# ##########
# ##########
# ##########
#
#
# 2020-10-13 17:52:14.119601
# ./pkl/experiments/_regression_gran1h_period2_lags1_model-tcn_user45_imp.pkl
# 1439/6912 fishished experiments
# ##########
# ##########
# ##########
#
#
# 2020-10-13 17:52:14.121645
# ./pkl/experiments/_regression_gran1h_period1_lags1_model-tcn_user45_imp.pkl
# 1440/6912 fishished experiments
# ##########
# ##########
# ##########
#
#
# 2020-10-13 17:52:14.122605
# ./pkl/experiments/_regression_gran30min_period4_lags8_model-tcn_user44_imp.pkl
# 1441/6912 fishished experiments
# ##########
# ##########
# ##########
#
#
# 2020-10-13 17:52:14.123603
# ./pkl/experiments/_regression_gran30min_period2_lags8_model-tcn_user44_imp.pkl
# 1442/6912 fishished experiments
# ##########
# ##########
# ##########
#
#
# 2020-10-13 17:52:14.124604
# ./pkl/experiments/_regression_gran30min_period1_lags8_model-tcn_user44_imp.pkl
# 1443/6912 fishished experiments
# ##########
# ##########
# ##########
#
#
# 2020-10-13 17:52:14.125602
# ./pkl/experiments/_regression_gran30min_period4_lags4_model-tcn_user44_imp.pkl
# 1444/6912 fishished experiments
# ##########
# ##########
# ##########
#
#
# 2020-10-13 17:52:14.128600
# ./pkl/experiments/_regression_gran30min_period2_lags4_model-tcn_user44_imp.pkl
# 1445/6912 fishished experiments
# ##########
# ##########
# ##########
#
#
# 2020-10-13 17:52:14.129601
# ./pkl/experiments/_regression_gran30min_period1_lags4_model-tcn_user44_imp.pkl
# 1446/6912 fishished experiments
# ##########
# ##########
# ##########
#
#
# 2020-10-13 17:52:14.130602
# ./pkl/experiments/_regression_gran30min_period4_lags2_model-tcn_user44_imp.pkl
# 1447/6912 fishished experiments
# ##########
# ##########
# ##########
#
#
# 2020-10-13 17:52:14.131602
# ./pkl/experiments/_regression_gran30min_period2_lags2_model-tcn_user44_imp.pkl
# 1448/6912 fishished experiments
# ##########
# ##########
# ##########
#
#
# 2020-10-13 17:52:14.141624
# ./pkl/experiments/_regression_gran30min_period1_lags2_model-tcn_user44_imp.pkl
# 1449/6912 fishished experiments
# ##########
# ##########
# ##########
#
#
# 2020-10-13 17:52:14.142600
# ./pkl/experiments/_regression_gran30min_period4_lags1_model-tcn_user44_imp.pkl
# 1450/6912 fishished experiments
# ##########
# ##########
# ##########
#
#
# 2020-10-13 17:52:14.142600
# ./pkl/experiments/_regression_gran30min_period2_lags1_model-tcn_user44_imp.pkl
# 1451/6912 fishished experiments
# ##########
# ##########
# ##########
#
#
# 2020-10-13 17:52:14.143601
# ./pkl/experiments/_regression_gran30min_period1_lags1_model-tcn_user44_imp.pkl
# 1452/6912 fishished experiments
# ##########
# ##########
# ##########
#
#
# 2020-10-13 17:52:14.144601
# ./pkl/experiments/_regression_gran1h_period4_lags8_model-tcn_user44_imp.pkl
# 1453/6912 fishished experiments
# ##########
# ##########
# ##########
#
#
# 2020-10-13 17:52:14.146603
# ./pkl/experiments/_regression_gran1h_period2_lags8_model-tcn_user44_imp.pkl
# 1454/6912 fishished experiments
# ##########
# ##########
# ##########
#
#
# 2020-10-13 17:52:14.147602
# ./pkl/experiments/_regression_gran1h_period1_lags8_model-tcn_user44_imp.pkl
# 1455/6912 fishished experiments
# ##########
# ##########
# ##########
#
#
# 2020-10-13 17:52:14.149603
# ./pkl/experiments/_regression_gran1h_period4_lags4_model-tcn_user44_imp.pkl
# 1456/6912 fishished experiments
# ##########
# ##########
# ##########
#
#
# 2020-10-13 17:52:14.149603
# ./pkl/experiments/_regression_gran1h_period2_lags4_model-tcn_user44_imp.pkl
# 1457/6912 fishished experiments
# ##########
# ##########
# ##########
#
#
# 2020-10-13 17:52:14.150603
# ./pkl/experiments/_regression_gran1h_period1_lags4_model-tcn_user44_imp.pkl
# 1458/6912 fishished experiments
# ##########
# ##########
# ##########
#
#
# 2020-10-13 17:52:14.150603
# ./pkl/experiments/_regression_gran1h_period4_lags2_model-tcn_user44_imp.pkl
# 1459/6912 fishished experiments
# ##########
# ##########
# ##########
#
#
# 2020-10-13 17:52:14.151600
# ./pkl/experiments/_regression_gran1h_period2_lags2_model-tcn_user44_imp.pkl
# 1460/6912 fishished experiments
# ##########
# ##########
# ##########
#
#
# 2020-10-13 17:52:14.152602
# ./pkl/experiments/_regression_gran1h_period1_lags2_model-tcn_user44_imp.pkl
# 1461/6912 fishished experiments
# ##########
# ##########
# ##########
#
#
# 2020-10-13 17:52:14.160646
# ./pkl/experiments/_regression_gran1h_period4_lags1_model-tcn_user44_imp.pkl
# 1462/6912 fishished experiments
# ##########
# ##########
# ##########
#
#
# 2020-10-13 17:52:14.163602
# ./pkl/experiments/_regression_gran1h_period2_lags1_model-tcn_user44_imp.pkl
# 1463/6912 fishished experiments
# ##########
# ##########
# ##########
#
#
# 2020-10-13 17:52:14.163602
# ./pkl/experiments/_regression_gran1h_period1_lags1_model-tcn_user44_imp.pkl
# 1464/6912 fishished experiments
# ##########
# ##########
# ##########
#
#
# 2020-10-13 17:52:14.163602
# ./pkl/experiments/_regression_gran30min_period4_lags8_model-tcn_user43_imp.pkl
# 1465/6912 fishished experiments
# ##########
# ##########
# ##########
#
#
# 2020-10-13 17:52:14.164604
# ./pkl/experiments/_regression_gran30min_period2_lags8_model-tcn_user43_imp.pkl
# 1466/6912 fishished experiments
# ##########
# ##########
# ##########
#
#
# 2020-10-13 17:52:14.172602
# ./pkl/experiments/_regression_gran30min_period1_lags8_model-tcn_user43_imp.pkl
# 1467/6912 fishished experiments
# ##########
# ##########
# ##########
#
#
# 2020-10-13 17:52:14.174604
# ./pkl/experiments/_regression_gran30min_period4_lags4_model-tcn_user43_imp.pkl
# 1468/6912 fishished experiments
# ##########
# ##########
# ##########
#
#
# 2020-10-13 17:52:14.177603
# ./pkl/experiments/_regression_gran30min_period2_lags4_model-tcn_user43_imp.pkl
# 1469/6912 fishished experiments
# ##########
# ##########
# ##########
#
#
# 2020-10-13 17:52:14.180602
# ./pkl/experiments/_regression_gran30min_period1_lags4_model-tcn_user43_imp.pkl
# 1470/6912 fishished experiments
# ##########
# ##########
# ##########
#
#
# 2020-10-13 17:52:14.182604
# ./pkl/experiments/_regression_gran30min_period4_lags2_model-tcn_user43_imp.pkl
# 1471/6912 fishished experiments
# ##########
# ##########
# ##########
#
#
# 2020-10-13 17:52:14.184601
# ./pkl/experiments/_regression_gran30min_period2_lags2_model-tcn_user43_imp.pkl
# 1472/6912 fishished experiments
# ##########
# ##########
# ##########
#
#
# 2020-10-13 17:52:14.187609
# ./pkl/experiments/_regression_gran30min_period1_lags2_model-tcn_user43_imp.pkl
# 1473/6912 fishished experiments
# ##########
# ##########
# ##########
#
#
# 2020-10-13 17:52:14.188604
# ./pkl/experiments/_regression_gran30min_period4_lags1_model-tcn_user43_imp.pkl
# 1474/6912 fishished experiments
# ##########
# ##########
# ##########
#
#
# 2020-10-13 17:52:14.188604
# ./pkl/experiments/_regression_gran30min_period2_lags1_model-tcn_user43_imp.pkl
# 1475/6912 fishished experiments
# ##########
# ##########
# ##########
#
#
# 2020-10-13 17:52:14.189602
# ./pkl/experiments/_regression_gran30min_period1_lags1_model-tcn_user43_imp.pkl
# 1476/6912 fishished experiments
# ##########
# ##########
# ##########
#
#
# 2020-10-13 17:52:14.191602
# ./pkl/experiments/_regression_gran1h_period4_lags8_model-tcn_user43_imp.pkl
# 1477/6912 fishished experiments
# ##########
# ##########
# ##########
#
#
# 2020-10-13 17:52:14.191602
# ./pkl/experiments/_regression_gran1h_period2_lags8_model-tcn_user43_imp.pkl
# 1478/6912 fishished experiments
# ##########
# ##########
# ##########
#
#
# 2020-10-13 17:52:14.194602
# ./pkl/experiments/_regression_gran1h_period1_lags8_model-tcn_user43_imp.pkl
# 1479/6912 fishished experiments
# ##########
# ##########
# ##########
#
#
# 2020-10-13 17:52:14.195604
# ./pkl/experiments/_regression_gran1h_period4_lags4_model-tcn_user43_imp.pkl
# 1480/6912 fishished experiments
# ##########
# ##########
# ##########
#
#
# 2020-10-13 17:52:14.195604
# ./pkl/experiments/_regression_gran1h_period2_lags4_model-tcn_user43_imp.pkl
# 1481/6912 fishished experiments
# ##########
# ##########
# ##########
#
#
# 2020-10-13 17:52:14.196603
# ./pkl/experiments/_regression_gran1h_period1_lags4_model-tcn_user43_imp.pkl
# 1482/6912 fishished experiments
# ##########
# ##########
# ##########
#
#
# 2020-10-13 17:52:14.197603
# ./pkl/experiments/_regression_gran1h_period4_lags2_model-tcn_user43_imp.pkl
# 1483/6912 fishished experiments
# ##########
# ##########
# ##########
#
#
# 2020-10-13 17:52:14.200602
# ./pkl/experiments/_regression_gran1h_period2_lags2_model-tcn_user43_imp.pkl
# 1484/6912 fishished experiments
# ##########
# ##########
# ##########
#
#
# 2020-10-13 17:52:14.202600
# ./pkl/experiments/_regression_gran1h_period1_lags2_model-tcn_user43_imp.pkl
# 1485/6912 fishished experiments
# ##########
# ##########
# ##########
#
#
# 2020-10-13 17:52:14.208628
# ./pkl/experiments/_regression_gran1h_period4_lags1_model-tcn_user43_imp.pkl
# 1486/6912 fishished experiments
# ##########
# ##########
# ##########
#
#
# 2020-10-13 17:52:14.209602
# ./pkl/experiments/_regression_gran1h_period2_lags1_model-tcn_user43_imp.pkl
# 1487/6912 fishished experiments
# ##########
# ##########
# ##########
#
#
# 2020-10-13 17:52:14.210602
# ./pkl/experiments/_regression_gran1h_period1_lags1_model-tcn_user43_imp.pkl
# 1488/6912 fishished experiments
# ##########
# ##########
# ##########
#
#
# 2020-10-13 17:52:14.210602
# ./pkl/experiments/_regression_gran30min_period4_lags8_model-tcn_user42_imp.pkl
# 1489/6912 fishished experiments
# ##########
# ##########
# ##########
#
#
# 2020-10-13 17:52:14.211614
# ./pkl/experiments/_regression_gran30min_period2_lags8_model-tcn_user42_imp.pkl
# 1490/6912 fishished experiments
# ##########
# ##########
# ##########
#
#
# 2020-10-13 17:52:14.211614
# ./pkl/experiments/_regression_gran30min_period1_lags8_model-tcn_user42_imp.pkl
# 1491/6912 fishished experiments
# ##########
# ##########
# ##########
#
#
# 2020-10-13 17:52:14.212601
# ./pkl/experiments/_regression_gran30min_period4_lags4_model-tcn_user42_imp.pkl
# 1492/6912 fishished experiments
# ##########
# ##########
# ##########
#
#
# 2020-10-13 17:52:14.214606
# (num_filters, kernel_size, dropout, use_skip_connections, use_batch_norm, nb_lags)
# dilations: 2
# receptive field:  4
# [6, 2, 0.8, 0, 1, 6, 7]
# *** *** *** *** *** *** *** *** *** ***
# Experiment is:
# _regression_gran30min_period2_lags4_model-tcn_user42_imp
# Beginning experiment:
# File reserved pkl/experiments/_regression_gran30min_period2_lags4_model-tcn_user42_imp.pkl
# Starting iteration nb 1 of 5
# WARNING:tensorflow:Large dropout rate: 0.8 (>0.5). In TensorFlow 2.x, dropout() uses dropout rate instead of keep_prob. Please ensure that this is intended.
# WARNING:tensorflow:Large dropout rate: 0.8 (>0.5). In TensorFlow 2.x, dropout() uses dropout rate instead of keep_prob. Please ensure that this is intended.
# WARNING:tensorflow:Large dropout rate: 0.8 (>0.5). In TensorFlow 2.x, dropout() uses dropout rate instead of keep_prob. Please ensure that this is intended.
# WARNING:tensorflow:Large dropout rate: 0.8 (>0.5). In TensorFlow 2.x, dropout() uses dropout rate instead of keep_prob. Please ensure that this is intended.
# WARNING:tensorflow:Large dropout rate: 0.8 (>0.5). In TensorFlow 2.x, dropout() uses dropout rate instead of keep_prob. Please ensure that this is intended.
# Restoring model weights from the end of the best epoch.
# Epoch 00052: early stopping
# Shapes for this iteration are:
# X_train: (25395, 4, 36)
# X_test: (402, 4, 36)
# Score: 0.177
# Time: 3.535
# Model: "tcn"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# residual_block_0 (ResidualBl multiple                  15808
# _________________________________________________________________
# residual_block_1 (ResidualBl multiple                  17024
# _________________________________________________________________
# lambda (Lambda)              multiple                  0
# _________________________________________________________________
# dense (Dense)                multiple                  65
# =================================================================
# Total params: 32,897
# Trainable params: 32,385
# Non-trainable params: 512
# _________________________________________________________________
# Starting iteration nb 2 of 5
# Restoring model weights from the end of the best epoch.
# Epoch 00063: early stopping
# Shapes for this iteration are:
# X_train: (42654, 4, 36)
# X_test: (261, 4, 36)
# Score: 0.206
# Time: 6.194
# Model: "tcn"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# residual_block_0 (ResidualBl multiple                  15808
# _________________________________________________________________
# residual_block_1 (ResidualBl multiple                  17024
# _________________________________________________________________
# lambda (Lambda)              multiple                  0
# _________________________________________________________________
# dense (Dense)                multiple                  65
# =================================================================
# Total params: 32,897
# Trainable params: 32,385
# Non-trainable params: 512
# _________________________________________________________________
# Starting iteration nb 3 of 5
# Shapes for this iteration are:
# X_train: (59771, 4, 36)
# X_test: (332, 4, 36)
# Score: 0.151
# Time: 8.63
# Model: "tcn"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# residual_block_0 (ResidualBl multiple                  15808
# _________________________________________________________________
# residual_block_1 (ResidualBl multiple                  17024
# _________________________________________________________________
# lambda (Lambda)              multiple                  0
# _________________________________________________________________
# dense (Dense)                multiple                  65
# =================================================================
# Total params: 32,897
# Trainable params: 32,385
# Non-trainable params: 512
# _________________________________________________________________
# Starting iteration nb 4 of 5
# Restoring model weights from the end of the best epoch.
# Epoch 00039: early stopping
# Shapes for this iteration are:
# X_train: (75085, 4, 36)
# X_test: (347, 4, 36)
# Score: 0.131
# Time: 6.537
# Model: "tcn"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# residual_block_0 (ResidualBl multiple                  15808
# _________________________________________________________________
# residual_block_1 (ResidualBl multiple                  17024
# _________________________________________________________________
# lambda (Lambda)              multiple                  0
# _________________________________________________________________
# dense (Dense)                multiple                  65
# =================================================================
# Total params: 32,897
# Trainable params: 32,385
# Non-trainable params: 512
# _________________________________________________________________
# Starting iteration nb 5 of 5
# Restoring model weights from the end of the best epoch.
# Epoch 00039: early stopping
# Shapes for this iteration are:
# X_train: (88989, 4, 36)
# X_test: (288, 4, 36)
# Score: 0.175
# Time: 7.764
# Model: "tcn"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# residual_block_0 (ResidualBl multiple                  15808
# _________________________________________________________________
# residual_block_1 (ResidualBl multiple                  17024
# _________________________________________________________________
# lambda (Lambda)              multiple                  0
# _________________________________________________________________
# dense (Dense)                multiple                  65
# =================================================================
# Total params: 32,897
# Trainable params: 32,385
# Non-trainable params: 512
# _________________________________________________________________
# scores: [0.177, 0.206, 0.151, 0.131, 0.175]
# nb_params: 32897
# time per iteration: [3.535, 6.194, 8.63, 6.537, 7.764]
# total time: 32.660000000000004
# Experiment finished
# 1493/6912 fishished experiments
# ##########
# ##########
# ##########
#
#
# 2020-10-13 18:25:09.162917
# ./pkl/experiments/_regression_gran30min_period1_lags4_model-tcn_user42_imp.pkl
# 1494/6912 fishished experiments
# ##########
# ##########
# ##########
#
#
# 2020-10-13 18:25:09.163917
# ./pkl/experiments/_regression_gran30min_period4_lags2_model-tcn_user42_imp.pkl
# 1495/6912 fishished experiments
# ##########
# ##########
# ##########
#
#
# 2020-10-13 18:25:09.166918
# ./pkl/experiments/_regression_gran30min_period2_lags2_model-tcn_user42_imp.pkl
# 1496/6912 fishished experiments
# ##########
# ##########
# ##########
#
#
# 2020-10-13 18:25:09.167917
# ./pkl/experiments/_regression_gran30min_period1_lags2_model-tcn_user42_imp.pkl
# 1497/6912 fishished experiments
# ##########
# ##########
# ##########
#
#
# 2020-10-13 18:25:09.167917
# ./pkl/experiments/_regression_gran30min_period4_lags1_model-tcn_user42_imp.pkl
# 1498/6912 fishished experiments
# ##########
# ##########
# ##########
#
#
# 2020-10-13 18:25:09.169919
# ./pkl/experiments/_regression_gran30min_period2_lags1_model-tcn_user42_imp.pkl
# 1499/6912 fishished experiments
# ##########
# ##########
# ##########
#
#
# 2020-10-13 18:25:09.174918
# ./pkl/experiments/_regression_gran30min_period1_lags1_model-tcn_user42_imp.pkl
# 1500/6912 fishished experiments
# ##########
# ##########
# ##########
#
#
# 2020-10-13 18:25:09.180919
# ./pkl/experiments/_regression_gran1h_period4_lags8_model-tcn_user42_imp.pkl
# 1501/6912 fishished experiments
# ##########
# ##########
# ##########
#
#
# 2020-10-13 18:25:09.189920
# ./pkl/experiments/_regression_gran1h_period2_lags8_model-tcn_user42_imp.pkl
# 1502/6912 fishished experiments
# ##########
# ##########
# ##########
#
#
# 2020-10-13 18:25:09.190918
# ./pkl/experiments/_regression_gran1h_period1_lags8_model-tcn_user42_imp.pkl
# 1503/6912 fishished experiments
# ##########
# ##########
# ##########
#
#
# 2020-10-13 18:25:09.192920
# ./pkl/experiments/_regression_gran1h_period4_lags4_model-tcn_user42_imp.pkl
# 1504/6912 fishished experiments
# ##########
# ##########
# ##########
#
#
# 2020-10-13 18:25:09.195919
# ./pkl/experiments/_regression_gran1h_period2_lags4_model-tcn_user42_imp.pkl
# 1505/6912 fishished experiments
# ##########
# ##########
# ##########
#
#
# 2020-10-13 18:25:09.196920
# ./pkl/experiments/_regression_gran1h_period1_lags4_model-tcn_user42_imp.pkl
# 1506/6912 fishished experiments
# ##########
# ##########
# ##########
#
#
# 2020-10-13 18:25:09.197919
# ./pkl/experiments/_regression_gran1h_period4_lags2_model-tcn_user42_imp.pkl
# 1507/6912 fishished experiments
# ##########
# ##########
# ##########
#
#
# 2020-10-13 18:25:09.198920
# ./pkl/experiments/_regression_gran1h_period2_lags2_model-tcn_user42_imp.pkl
# 1508/6912 fishished experiments
# ##########
# ##########
# ##########
#
#
# 2020-10-13 18:25:09.198920
# ./pkl/experiments/_regression_gran1h_period1_lags2_model-tcn_user42_imp.pkl
# 1509/6912 fishished experiments
# ##########
# ##########
# ##########
#
#
# 2020-10-13 18:25:09.199920
# (num_filters, kernel_size, dropout, use_skip_connections, use_batch_norm, nb_lags)
# dilations: 2
# receptive field:  4
# [6, 2, 0.8, 0, 1, 6, 7]
# *** *** *** *** *** *** *** *** *** ***
# Experiment is:
# _regression_gran1h_period4_lags1_model-tcn_user42_imp
# Beginning experiment:
# File reserved pkl/experiments/_regression_gran1h_period4_lags1_model-tcn_user42_imp.pkl
# Starting iteration nb 1 of 5
# Shapes for this iteration are:
# X_train: (12902, 1, 36)
# X_test: (201, 1, 36)
# Score: 0.124
# Time: 1.842
# Model: "tcn"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# residual_block_0 (ResidualBl multiple                  15808
# _________________________________________________________________
# residual_block_1 (ResidualBl multiple                  17024
# _________________________________________________________________
# lambda (Lambda)              multiple                  0
# _________________________________________________________________
# dense (Dense)                multiple                  65
# =================================================================
# Total params: 32,897
# Trainable params: 32,385
# Non-trainable params: 512
# _________________________________________________________________
# Starting iteration nb 2 of 5
# Restoring model weights from the end of the best epoch.
# Epoch 00047: early stopping
# Shapes for this iteration are:
# X_train: (21611, 1, 36)
# X_test: (132, 1, 36)
# Score: 0.132
# Time: 2.113
# Model: "tcn"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# residual_block_0 (ResidualBl multiple                  15808
# _________________________________________________________________
# residual_block_1 (ResidualBl multiple                  17024
# _________________________________________________________________
# lambda (Lambda)              multiple                  0
# _________________________________________________________________
# dense (Dense)                multiple                  65
# =================================================================
# Total params: 32,897
# Trainable params: 32,385
# Non-trainable params: 512
# _________________________________________________________________
# Starting iteration nb 3 of 5
# Restoring model weights from the end of the best epoch.
# Epoch 00044: early stopping
# Shapes for this iteration are:
# X_train: (30315, 1, 36)
# X_test: (168, 1, 36)
# Score: 0.085
# Time: 3.494
# Model: "tcn"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# residual_block_0 (ResidualBl multiple                  15808
# _________________________________________________________________
# residual_block_1 (ResidualBl multiple                  17024
# _________________________________________________________________
# lambda (Lambda)              multiple                  0
# _________________________________________________________________
# dense (Dense)                multiple                  65
# =================================================================
# Total params: 32,897
# Trainable params: 32,385
# Non-trainable params: 512
# _________________________________________________________________
# Starting iteration nb 4 of 5
# Restoring model weights from the end of the best epoch.
# Epoch 00041: early stopping
# Shapes for this iteration are:
# X_train: (38076, 1, 36)
# X_test: (177, 1, 36)
# Score: 0.115
# Time: 3.983
# Model: "tcn"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# residual_block_0 (ResidualBl multiple                  15808
# _________________________________________________________________
# residual_block_1 (ResidualBl multiple                  17024
# _________________________________________________________________
# lambda (Lambda)              multiple                  0
# _________________________________________________________________
# dense (Dense)                multiple                  65
# =================================================================
# Total params: 32,897
# Trainable params: 32,385
# Non-trainable params: 512
# _________________________________________________________________
# Starting iteration nb 5 of 5
# Restoring model weights from the end of the best epoch.
# Epoch 00046: early stopping
# Shapes for this iteration are:
# X_train: (45133, 1, 36)
# X_test: (145, 1, 36)
# Score: 0.127
# Time: 5.45
# Model: "tcn"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# residual_block_0 (ResidualBl multiple                  15808
# _________________________________________________________________
# residual_block_1 (ResidualBl multiple                  17024
# _________________________________________________________________
# lambda (Lambda)              multiple                  0
# _________________________________________________________________
# dense (Dense)                multiple                  65
# =================================================================
# Total params: 32,897
# Trainable params: 32,385
# Non-trainable params: 512
# _________________________________________________________________
# scores: [0.124, 0.132, 0.085, 0.115, 0.127]
# nb_params: 32897
# time per iteration: [1.842, 2.113, 3.494, 3.983, 5.45]
# total time: 16.882
# Experiment finished
# 1510/6912 fishished experiments
# ##########
# ##########
# ##########
#
#
# 2020-10-13 18:42:11.052007
# ./pkl/experiments/_regression_gran1h_period2_lags1_model-tcn_user42_imp.pkl
# 1511/6912 fishished experiments
# ##########
# ##########
# ##########
#
#
# 2020-10-13 18:42:11.062006
# (num_filters, kernel_size, dropout, use_skip_connections, use_batch_norm, nb_lags)
# dilations: 2
# receptive field:  4
# [6, 2, 0.8, 0, 1, 6, 7]
# *** *** *** *** *** *** *** *** *** ***
# Experiment is:
# _regression_gran1h_period1_lags1_model-tcn_user42_imp
# Beginning experiment:
# File reserved pkl/experiments/_regression_gran1h_period1_lags1_model-tcn_user42_imp.pkl
# Starting iteration nb 1 of 5
# Shapes for this iteration are:
# X_train: (9645, 1, 36)
# X_test: (214, 1, 36)
# Score: 0.145
# Time: 1.771
# Model: "tcn"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# residual_block_0 (ResidualBl multiple                  15808
# _________________________________________________________________
# residual_block_1 (ResidualBl multiple                  17024
# _________________________________________________________________
# lambda (Lambda)              multiple                  0
# _________________________________________________________________
# dense (Dense)                multiple                  65
# =================================================================
# Total params: 32,897
# Trainable params: 32,385
# Non-trainable params: 512
# _________________________________________________________________
# Starting iteration nb 2 of 5

# %%
import os
import pickle as pkl
from experiments.experiment_running import run_all_experiments
def fitness():
    pass
run_all_experiments(reverse_order=True, experiment_verbose=2, fit_verbose=0, model_verbose=1)g
# Out:
# Using TensorFlow backend.
# 2020-10-05 23:31:19.314492
# ./pkl/experiments/_regression_gran30min_period4_lags8_model-mlp_user59_imp.pkl
# ####
# 1/6912 fishished experiments
# ####
# 2020-10-05 23:31:19.317496
# ./pkl/experiments/_regression_gran30min_period2_lags8_model-mlp_user59_imp.pkl
# ####
# 2/6912 fishished experiments
# ####
# 2020-10-05 23:31:19.322565
# ./pkl/experiments/_regression_gran30min_period1_lags8_model-mlp_user59_imp.pkl
# ####
# 3/6912 fishished experiments
# ####
# 2020-10-05 23:31:19.326590
# ./pkl/experiments/_regression_gran30min_period4_lags4_model-mlp_user59_imp.pkl
# ####
# 4/6912 fishished experiments
# ####
# 2020-10-05 23:31:19.327546
# ./pkl/experiments/_regression_gran30min_period2_lags4_model-mlp_user59_imp.pkl
# ####
# 5/6912 fishished experiments
# ####
# 2020-10-05 23:31:19.328545
# ./pkl/experiments/_regression_gran30min_period1_lags4_model-mlp_user59_imp.pkl
# ####
# 6/6912 fishished experiments
# ####
# 2020-10-05 23:31:19.332544
# ...

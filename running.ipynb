# %%
import os
import pickle as pkl
from experiments.experiment_running import run_all_experiments
def fitness():
    pass
run_all_experiments(reverse_order=True, experiment_verbose=2, fit_verbose=0, model_verbose=0)
# Out:
# eriments
# ##########
# ##########
# ##########
#
#
# 2020-10-07 16:51:07.793804
# ./pkl/experiments/_regression_gran30min_period1_lags1_model-mlp_user0_imp.pkl
# 1140/6912 fishished experiments
# ##########
# ##########
# ##########
#
#
# 2020-10-07 16:51:07.793804
# ./pkl/experiments/_regression_gran1h_period4_lags8_model-mlp_user0_imp.pkl
# 1141/6912 fishished experiments
# ##########
# ##########
# ##########
#
#
# 2020-10-07 16:51:07.794807
# ./pkl/experiments/_regression_gran1h_period2_lags8_model-mlp_user0_imp.pkl
# 1142/6912 fishished experiments
# ##########
# ##########
# ##########
#
#
# 2020-10-07 16:51:07.795805
# ./pkl/experiments/_regression_gran1h_period1_lags8_model-mlp_user0_imp.pkl
# 1143/6912 fishished experiments
# ##########
# ##########
# ##########
#
#
# 2020-10-07 16:51:07.795805
# ./pkl/experiments/_regression_gran1h_period4_lags4_model-mlp_user0_imp.pkl
# 1144/6912 fishished experiments
# ##########
# ##########
# ##########
#
#
# ...
